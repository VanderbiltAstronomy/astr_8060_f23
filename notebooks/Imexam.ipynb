# %% [markdown]
# # Using imexam to display images in DS9

# %%
# import block
import numpy as np
from astropy.io import fits
import pdb
# %matplotlib inline
import imexam
import os
# Out:
# Ginga not installed, use other viewer, or no viewer

# %%
data_dir    = '/Users/runnojc1/Dropbox/Research/teaching/S2021/ASTR8060/Imaging/'
reduced_dir = '/Users/runnojc1/Dropbox/Research/teaching/S2021/ASTR8060/work/reductions/reduced/'

# %%
# open a DS9 with a particular name
os.system("/Volumes/Shasta/Applications/SAOImageDS9.app/Contents/MacOS/ds9 -title ds9_1 &")
# Out:
# 0

# %%
# connect the imexam viewer to that window
viewer=imexam.connect('ds9_1')

# %%
# load an image and zscale
viewer.load_fits(reduced_dir+'a085otz.fits')
viewer.scale()

# %%
# run imexam
# holding the mouse over a star and pressing 
# 'r' will return the results of a radial plot
viewer.imexam()
# Out:
# Press 'q' to quit
#
# 2 Make the next plot in a new window
# a Aperture sum, with radius region_size
# b Return the 2D gauss fit center of the object
# c Return column plot
# d Return the Center of Mass fit center of the object
# e Return a contour plot in a region around the cursor
# g Return curve of growth plot
# h Return a histogram in the region around the cursor
# j 1D [Gaussian1D default] line fit
# k 1D [Gaussian1D default] column fit
# l Return line plot
# m Square region stats, in [region_size],default is median
# r Return the radial profile plot
# s Save current figure to disk as [plot_name]
# t Make a fits image cutout using pointer location
# w Display a surface plot around the cursor location
# x Return x,y,value of pixel
# y Return x,y,value of pixel
# Current image /Users/runnojc1/Dropbox/Research/teaching/S2021/ASTR8060/work/reductions/reduced/a085otz.fits
# xc=1044.8030	yc=1043.2159
# Background per pixel: 131.1625273621053
# Max. pix. flux =  7318.095
# ...
